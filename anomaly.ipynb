# %%
import pandas as pd

# %%
from pyod.models.knn import KNN

# %%
df = pd.read_csv("rca_2020_04_21.csv")

# %%
df.head(1000)
# Out:
#                  trace_id      timestamp  latency  succ      source  \
# 0    868d91717444d4112006  1587398400084      4.0  True  docker_005
# 1    868d91717444d4112006  1587398400090      2.0  True  docker_005
# 2    868d91717444d4112006  1587398400084      2.0  True  docker_005
# 3    868d91717444d4112006  1587398400054     40.0  True  docker_004
# 4    868d91717444d4112006  1587398400053      0.0  True  docker_004
# ..                    ...            ...      ...   ...         ...
# 995  49c871717444e57b5322  1587398404554      1.0  True  docker_005
# 996  49c871717444e57b5322  1587398404537     17.0  True  docker_003
# 997  49c871717444e57b5322  1587398404536      0.0  True  docker_003
# 998  49c871717444e57b5322  1587398404573      3.0  True  docker_005
# 999  49c871717444e57b5322  1587398404578      2.0  True  docker_005
#
#          target
# 0        db_003
# 1        db_003
# 2    docker_005
# 3    docker_005
# 4    docker_004
# ..          ...
# 995  docker_005
# ...

# %%
detector = KNN()
detector.fit(df.iloc[:,1:5])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [16], in <cell line: 2>()
#       1 detector = KNN()
# ----> 2 detector.fit(df.iloc[:,1:5])
#
# File /mnt/c/workspace/anomalydetetion/pyod/models/knn.py:190, in KNN.fit(self, X, y)
#     173 """Fit detector. y is ignored in unsupervised methods.
#     174
#     175 Parameters
#    (...)
#     186     Fitted estimator.
#     187 """
#     189 # validate inputs X and y (optional)
# --> 190 X = check_array(X)
#     191 self._set_n_classes(y)
#     193 self.neigh_.fit(X)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:746, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     744         array = array.astype(dtype, casting="unsafe", copy=False)
#     745     else:
# ...
